# %% [markdown]
# ### Task

# %% [markdown]
# 1. Dump the given .sql files (each file represents a single table) into your MySQL database.
# 2. Explore the provided tables and perform some level of EDA (either using Python libraries or using SQL query) to get insights about the data.*
# 3. Perform monthly and weekly level product wise aggregations of the transactions for each user and maintain both in separate tables.
# 4. Calculate all the facts required for customer profile table using any convenient tool (Python or SQL or Spark) utilizing the aggregate table created in step 3.
# 5. Create an Airflow DAG that will execute the script or code for steps 3 and 4 sequentially which can be scheduled as per the requirement (daily or hourly).

# %%
import pandas as pd

from mysql_connector.mysql_connection import table_df

# %% [markdown]
# ### Loading Tables

# %%
customer_profile = table_df('customer', 'customer_profile')

rw_transaction_data = table_df('customer', 'rw_transaction_data')
products = table_df('customer', 'products')
product_category = table_df('customer', 'product_category')
product_category_map = table_df('customer', 'product_category_map')

# %% [markdown]
# ### Customer Profile

# %%
customer_profile.head()
# Out:
#    account_id  reward_point  total_inflow_amount  total_outflow_amount  \
# 0           1        1574.0              76385.0               70045.0
# 1           2         306.0             557075.0              184405.0
# 2           3          10.0              18415.0               12400.0
# 3           4         324.0               6350.0                3050.0
# 4           5         929.0             168576.0              100385.0
#
#    total_valuechain_amount  total_inflow_count  total_outflow_count  \
# 0                   7650.0                  39                   31
# 1                 344798.0                 753                  142
# 2                   5110.0                   6                    5
# 3                   7499.0                   4                    3
# 4                  53911.0                  69                   24
#
#    total_valuechain_count  monthly_inflow_amount  monthly_outflow_amount  ...  \
# 0                       4                76385.0                 70045.0  ...
# 1                     400                16005.0                  6180.0  ...
# 2                       9                18415.0                 12400.0  ...
# 3                       8                 6350.0                  3050.0  ...
# 4                      95               106106.0                 88660.0  ...
#
#    latest_used_product  latest_tran_date  this_month_revenue  \
# 0           Send Money        2081-01-26                31.0
# 1      Fonepay Payment        2081-01-31                 4.0
# 2     NT Prepaid Topup        2081-01-31                16.0
# 3      Fonepay Payment        2081-01-21                21.0
# 4      Fonepay Payment        2081-01-31                70.0
#
#    monthly_average_lifetime_revenue total_revenue product_usage  \
# 0                              31.0          31.0            14
# 1                              62.0        2727.0            47
# 2                              16.0          16.0             8
# 3                              21.0          21.0             8
# 4                              28.0        1226.0            37
#
#    most_used_product  second_most_used_product  \
# 0         Send Money           Fonepay Payment
# 1   NT Prepaid Topup                Send Money
# 2        Ncell Topup                Send Money
# 3    Fonepay Payment                Send Money
# 4   NT Prepaid Topup         NT Postpaid Topup
#
#             third_most_used_product    run_date
# 0  eSewa to Laxmi Sunrise Bank Ltd.  2024-01-05
# 1                       Ncell Topup  2024-01-05
# 2                   Fonepay Payment  2024-01-05
# 3                       Electricity  2024-01-05
# 4                        Send Money  2024-01-05
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Transaction Data

# %%
rw_transaction_data.head()
# Out:
#       txn_id last_modified_date last_modified_date_bs created_date  amount  \
# 0  660612529         2023-03-29            2079-12-15   2022-11-23    50.0
# 1  666435422         2022-12-01            2079-08-15   2022-12-01   750.0
# 2  666436001         2022-12-01            2079-08-15   2022-12-01    50.0
# 3  666436068         2022-12-01            2079-08-15   2022-12-01    50.0
# 4  666437220         2022-12-01            2079-08-15   2022-12-01   100.0
#
#    status  module_id  product_id  product_type_id  payer_account_id  \
# 0       1          1          77               29               531
# 1       1          1          76               29               531
# 2       1          1          77               29               531
# 3       1          1          77               29               531
# 4       1          1          30               29               531
#
#    receiver_account_id  reward_point  cash_back_amount  revenue_amount  \
# 0                    2           0.0              0.00            0.00
# 1                   81           0.0              0.00           33.75
# 2                    2           0.0              1.38            0.00
# 3                  647           0.0              1.38            0.00
# 4                  907           0.0              3.90            0.00
#
#    transactor_module_id      time
# 0                     4  14:07:40
# 1                     4  00:03:41
# 2                     4  00:06:20
# 3                     4  00:06:32
# 4                     4  00:12:51

# %%
rw_transaction_data.shape
# Out:
# (193367, 16)

# %% [markdown]
# ### Product and Product Category

# %%
products.head()
# Out:
#    module_id  product_id  product_type_id               product_name  \
# 0          1          77               29       Ncell Topup via Bank
# 1          1          76               29      SIM TV TOPUP VIA BANK
# 2          1          30               29          NT Topup via Bank
# 3          1         133               29    Wordlink Topup via Bank
# 4          1          89               29  Smart Cell Topup via Bank
#
#      product_type_name
# 0  Card Server Payment
# 1  Card Server Payment
# 2  Card Server Payment
# 3  Card Server Payment
# 4  Card Server Payment

# %%
product_category.head()
# Out:
#    id                category_name                  description  parent_id  \
# 0   1           Telecommunications           Telecommunications        NaN
# 1   2                      Utility                      Utility        NaN
# 2   3           TV-Internet-Movies           TV-Internet-Movies        NaN
# 3   4  Travel and Airline Services  Travel and Airline Services        NaN
# 4   5                 Ride Sharing                 Ride Sharing        NaN
#
#    status  active_flag          created_on updated_on
# 0       0            1 2024-04-21 09:42:39       None
# 1       0            1 2024-04-21 09:42:39       None
# 2       0            1 2024-04-21 09:42:39       None
# 3       0            1 2024-04-21 09:42:39       None
# 4       0            1 2024-04-21 09:42:39       None

# %%
product_category.drop('updated_on', inplace=True, axis=1)

# %%
product_category.rename(columns={'id': 'product_category_id'}, inplace=True)

# %%
product_category_map.head()
# Out:
#    module_id  product_id  product_type_id  \
# 0          1         670               11
# 1          2        2545                3
# 2          2        1444                6
# 3          2        1008                7
# 4          2         885               10
#
#                                   product_name  product_category_id  \
# 0  Siddhartha Sishu Sadan, Ln Chowk, Dhangadhi                 33.0
# 1                Multipurpose Finance Transfer                  NaN
# 2                   Century Corporate Transfer                  NaN
# 3              Srijana Corporate Fund Receiver                  NaN
# 4                          Pokhara_Convergence                  NaN
#
#       txn_flow
# 0  Value Chain
# 1      OutFlow
# 2      OutFlow
# 3      OutFlow
# 4      OutFlow

# %% [markdown]
# #### Cleaning product_category_map

# %%
product_category_map[product_category_map.duplicated(subset =['product_id', 'module_id', 'product_type_id'])]
# Out:
#     module_id  product_id  product_type_id          product_name  \
# 16          1          77               29  Ncell Topup via Bank
# 17          1           4               25           Ncell Topup
# 23          1          21               24     NT Postpaid Topup
# 25          1          19               35      NT Prepaid Topup
# 62          1         218               37            Ncell Pack
# 63          1         287               29   Ncell Data Via Bank
# 94          1         325               80        eScrow Service
# 95          1           8               12         Epay Donation
# 96          1           2               12            Send Money
# 97          1          19               12            OLDBALANCE
# 98          1          91               80               Cash In
#
#     product_category_id     txn_flow
# 16                 14.0  Value Chain
# 17                 14.0  Value Chain
# 23                 14.0  Value Chain
# 25                 14.0  Value Chain
# 62                 14.0  Value Chain
# 63                 14.0  Value Chain
# 94                 92.0      OutFlow
# 95                 90.0      OutFlow
# 96                 90.0      OutFlow
# 97                 90.0      OutFlow
# 98                 90.0      OutFlow

# %%
product_category_map[(product_category_map['module_id'] == 1) & 
                     (product_category_map['product_id'] == 19) & 
                     (product_category_map['product_type_id'] == 35)]
# Out:
#     module_id  product_id  product_type_id      product_name  \
# 7           1          19               35     Prepaid Topup
# 25          1          19               35  NT Prepaid Topup
#
#     product_category_id     txn_flow
# 7                   NaN  Value Chain
# 25                 14.0  Value Chain

# %%
product_category_map[(product_category_map['module_id'] == 1) & 
                     (product_category_map['product_id'] == 325) & 
                     (product_category_map['product_type_id'] == 80)]
# Out:
#     module_id  product_id  product_type_id    product_name  \
# 87          1         325               80  eScrow Service
# 94          1         325               80  eScrow Service
#
#     product_category_id txn_flow
# 87                 92.0   InFlow
# 94                 92.0  OutFlow

# %%
product_category_map = product_category_map.loc[:, ['product_id', 'module_id', 'product_type_id', 'txn_flow']]

# %%
product_category_map.duplicated().sum()
# Out:
# 6

# %%
product_category_map.drop_duplicates(inplace=True)

# %% [markdown]
# ### Complex Join
#
# - Join of all tables

# %%
merged_df_1 = pd.merge(rw_transaction_data, products, on = ['product_id', 'product_type_id', 'module_id'], how = 'inner')
merged_df_1.head()
# Out:
#       txn_id last_modified_date last_modified_date_bs created_date  amount  \
# 0  660612529         2023-03-29            2079-12-15   2022-11-23    50.0
# 1  666435422         2022-12-01            2079-08-15   2022-12-01   750.0
# 2  666436001         2022-12-01            2079-08-15   2022-12-01    50.0
# 3  666436068         2022-12-01            2079-08-15   2022-12-01    50.0
# 4  666437220         2022-12-01            2079-08-15   2022-12-01   100.0
#
#    status  module_id  product_id  product_type_id  payer_account_id  \
# 0       1          1          77               29               531
# 1       1          1          76               29               531
# 2       1          1          77               29               531
# 3       1          1          77               29               531
# 4       1          1          30               29               531
#
#    receiver_account_id  reward_point  cash_back_amount  revenue_amount  \
# 0                    2           0.0              0.00            0.00
# 1                   81           0.0              0.00           33.75
# 2                    2           0.0              1.38            0.00
# 3                  647           0.0              1.38            0.00
# 4                  907           0.0              3.90            0.00
#
#    transactor_module_id      time           product_name    product_type_name
# 0                     4  14:07:40   Ncell Topup via Bank  Card Server Payment
# 1                     4  00:03:41  SIM TV TOPUP VIA BANK  Card Server Payment
# 2                     4  00:06:20   Ncell Topup via Bank  Card Server Payment
# 3                     4  00:06:32   Ncell Topup via Bank  Card Server Payment
# 4                     4  00:12:51      NT Topup via Bank  Card Server Payment

# %%
merged_df_1.shape
# Out:
# (193367, 18)

# %%
merged_df_1.nunique()
# Out:
# txn_id                   193367
# last_modified_date          144
# last_modified_date_bs       144
# created_date                145
# amount                     6343
# status                        1
# module_id                     2
# product_id                  399
# product_type_id              33
# payer_account_id              9
# receiver_account_id        1621
# reward_point                 33
# cash_back_amount            823
# revenue_amount              467
# transactor_module_id          2
# time                      57786
# product_name                386
# product_type_name            35
# dtype: int64

# %%
merged_df_2 = pd.merge(merged_df_1, product_category_map, on = ['product_id', 'product_type_id', 'module_id'], how='inner')

# %%
merged_df_2.head()
# Out:
#       txn_id last_modified_date last_modified_date_bs created_date  amount  \
# 0  660612529         2023-03-29            2079-12-15   2022-11-23    50.0
# 1  666435422         2022-12-01            2079-08-15   2022-12-01   750.0
# 2  666436001         2022-12-01            2079-08-15   2022-12-01    50.0
# 3  666436068         2022-12-01            2079-08-15   2022-12-01    50.0
# 4  666437220         2022-12-01            2079-08-15   2022-12-01   100.0
#
#    status  module_id  product_id  product_type_id  payer_account_id  \
# 0       1          1          77               29               531
# 1       1          1          76               29               531
# 2       1          1          77               29               531
# 3       1          1          77               29               531
# 4       1          1          30               29               531
#
#    receiver_account_id  reward_point  cash_back_amount  revenue_amount  \
# 0                    2           0.0              0.00            0.00
# 1                   81           0.0              0.00           33.75
# 2                    2           0.0              1.38            0.00
# 3                  647           0.0              1.38            0.00
# 4                  907           0.0              3.90            0.00
#
#    transactor_module_id      time           product_name    product_type_name  \
# 0                     4  14:07:40   Ncell Topup via Bank  Card Server Payment
# 1                     4  00:03:41  SIM TV TOPUP VIA BANK  Card Server Payment
# 2                     4  00:06:20   Ncell Topup via Bank  Card Server Payment
# 3                     4  00:06:32   Ncell Topup via Bank  Card Server Payment
# 4                     4  00:12:51      NT Topup via Bank  Card Server Payment
#
#       txn_flow
# 0  Value Chain
# 1  Value Chain
# 2  Value Chain
# 3  Value Chain
# 4  Value Chain

# %%
# merged_df_2.rename(columns={'product_name_x': 'product_name'}, inplace=True)

# %%
merged_df_2.shape
# Out:
# (151729, 19)

# %%
merged_df_2.nunique()
# Out:
# txn_id                   147309
# last_modified_date          144
# last_modified_date_bs       144
# created_date                145
# amount                     2545
# status                        1
# module_id                     2
# product_id                  155
# product_type_id              24
# payer_account_id              9
# receiver_account_id        1409
# reward_point                 28
# cash_back_amount            791
# revenue_amount              439
# transactor_module_id          2
# time                      55637
# product_name                155
# product_type_name            26
# txn_flow                      3
# dtype: int64

# %%
# merged_df_3 = pd.merge(merged_df_2, product_category, on = ['product_category_id'], how='left')
# merged_df_3.shape

# %%
df = merged_df_2.copy()

# %%
df.shape
# Out:
# (151729, 19)

# %% [markdown]
# ### ID to String

# %%
df[['txn_id', 'module_id', 'product_id', 'product_type_id', 'payer_account_id', 'receiver_account_id', 'transactor_module_id']] = \
    df[['txn_id', 'module_id', 'product_id', 'product_type_id', 'payer_account_id', 'receiver_account_id', 'transactor_module_id']].apply(lambda x: x.astype(str))

# %% [markdown]
# ### Date

# %%
df['last_modified_date'] = df['last_modified_date'].astype(str)

# %%
df['dates'] = pd.to_datetime(df['last_modified_date'] + df['time'], format='%Y-%m-%d%H:%M:%S')

# %%
df[['last_modified_date', 'time', 'dates']]
# Out:
#        last_modified_date      time               dates
# 0              2023-03-29  14:07:40 2023-03-29 14:07:40
# 1              2022-12-01  00:03:41 2022-12-01 00:03:41
# 2              2022-12-01  00:06:20 2022-12-01 00:06:20
# 3              2022-12-01  00:06:32 2022-12-01 00:06:32
# 4              2022-12-01  00:12:51 2022-12-01 00:12:51
# ...                   ...       ...                 ...
# 151724         2023-05-24  23:18:08 2023-05-24 23:18:08
# 151725         2023-05-24  23:21:16 2023-05-24 23:21:16
# 151726         2023-05-24  23:30:13 2023-05-24 23:30:13
# 151727         2023-05-24  23:47:34 2023-05-24 23:47:34
# 151728         2023-05-24  23:59:25 2023-05-24 23:59:25
#
# [151729 rows x 3 columns]

# %%
# df['last_modified_date'] = pd.to_datetime(df['last_modified_date'], errors = 'coerce') 
df[['last_modified_date', 'last_modified_date_bs', 'created_date']] = df[['last_modified_date', 'last_modified_date_bs', 'created_date']].apply(pd.to_datetime, errors='coerce')
df['time'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.time

# Creating monthly and weekly columns
df['monthly'] = df['last_modified_date'].dt.month
df['weekly'] = df['last_modified_date'].dt.isocalendar().week

# %% [markdown]
# ### TXN Flow

# %%
pivot_monthly = pd.pivot_table(df, index = ['payer_account_id', 'monthly'], columns = 'txn_flow', values = 'amount', aggfunc = 'sum').reset_index()
pivot_monthly
# Out:
# txn_flow payer_account_id  monthly      InFlow     OutFlow  Value Chain
# 0                    1056        1       755.0       755.0        325.0
# 1                    1056        2      5500.0      5500.0        674.0
# 2                    1056        3         NaN         NaN       1039.0
# 3                    1056        4         NaN      3000.0        855.0
# 4                    1056        5         NaN         NaN       1554.0
# 5                    1056       12         NaN         NaN        200.0
# 6                    1176        3         NaN         NaN         10.0
# 7                     222        1       170.0       170.0       1045.0
# 8                     222        2       250.0       250.0       1535.0
# 9                     222        3         NaN         NaN        350.0
# 10                    222        4         NaN      2000.0       3180.0
# 11                    222        5         NaN       650.0       1390.0
# 12                    222       12         NaN         NaN        135.0
# 13                     26        1    233641.0    366391.0     122018.0
# 14                     26        2    261970.0    631800.0      64076.0
# 15                     26        3    289840.0    758290.0     208047.0
# 16                     26        4    320520.0    722920.0     224471.0
# 17                     26        5    331040.0    518490.0     138116.0
# 18                     26       12         NaN         NaN        280.0
# 19                     34        1  12991992.0  13915812.0    1155866.0
# 20                     34        2  11958637.0  12463831.0     810107.0
# 21                     34        3  13592665.0  14212535.0     924217.0
# 22                     34        4  13086915.0  13646190.0     671489.0
# 23                     34        5  10756510.0  11154235.0     521381.0
# 24                     34       12     83200.0     88200.0       3251.0
# 25                    471        1     10000.0     11000.0      58858.0
# 26                    471        2      4960.0      4960.0      48180.0
# 27                    471        3     15920.0     15920.0      65305.0
# 28                    471        4     18040.0     18040.0      59856.0
# 29                    471        5      5400.0      5400.0      38352.0
# 30                    471       12         NaN         NaN       1524.0
# 31                    531        1         NaN         NaN    5393452.0
# 32                    531        2         NaN         NaN    3972487.0
# 33                    531        3         NaN         NaN    5146006.0
# 34                    531        4         NaN         NaN    9261552.0
# 35                    531        5         NaN         NaN    7514307.0
# 36                    531       12         NaN         NaN     455507.0
# 37                    538        5         NaN         NaN         10.0
# 38                     56        1    114575.0    898575.0     302659.0
# 39                     56        2     93756.0    645756.0     284844.0
# 40                     56        3    144065.0    907835.0     337263.0
# 41                     56        4    146656.0    834851.0     360076.0
# 42                     56        5     81545.0    710800.0     336341.0
# 43                     56       12      9725.0     12125.0      16661.0

# %%
aggregrated_df_monthly = (
    pivot_monthly
    .groupby('payer_account_id')
    .agg(
        total_inflow_amount = ('InFlow', 'sum'),
        total_outflow_amount = ('OutFlow', 'sum'),
        total_valuechain_amount = ('Value Chain', 'sum'),
        monthly_inflow_amount = ('InFlow', 'mean'),
        monthly_outflow_amount = ('OutFlow', 'mean'),
        monthly_valuechain_amount = ('Value Chain', 'mean'),
    )
    .reset_index()
)
aggregrated_df_monthly
# Out:
#   payer_account_id  total_inflow_amount  total_outflow_amount  \
# 0             1056               6255.0                9255.0
# 1             1176                  0.0                   0.0
# 2              222                420.0                3070.0
# 3               26            1437011.0             2997891.0
# 4               34           62469919.0            65480803.0
# 5              471              54320.0               55320.0
# 6              531                  0.0                   0.0
# 7              538                  0.0                   0.0
# 8               56             590322.0             4009942.0
#
#    total_valuechain_amount  monthly_inflow_amount  monthly_outflow_amount  \
# 0                   4647.0           3.127500e+03            3.085000e+03
# 1                     10.0                    NaN                     NaN
# 2                   7635.0           2.100000e+02            7.675000e+02
# 3                 757008.0           2.874022e+05            5.995782e+05
# 4                4086311.0           1.041165e+07            1.091347e+07
# 5                 272075.0           1.086400e+04            1.106400e+04
# 6               31743311.0                    NaN                     NaN
# 7                     10.0                    NaN                     NaN
# 8                1637844.0           9.838700e+04            6.683237e+05
#
#    monthly_valuechain_amount
# 0               7.745000e+02
# 1               1.000000e+01
# 2               1.272500e+03
# 3               1.261680e+05
# 4               6.810518e+05
# 5               4.534583e+04
# 6               5.290552e+06
# 7               1.000000e+01
# 8               2.729740e+05

# %%
pivot_monthly_count = pd.pivot_table(df, index = ['payer_account_id', 'monthly'], columns = 'txn_flow', values = 'amount', aggfunc = 'count').reset_index()
pivot_monthly_count
# Out:
# txn_flow payer_account_id  monthly  InFlow  OutFlow  Value Chain
# 0                    1056        1     1.0      1.0          4.0
# 1                    1056        2     1.0      1.0          7.0
# 2                    1056        3     NaN      NaN          8.0
# 3                    1056        4     NaN      1.0          4.0
# 4                    1056        5     NaN      NaN         10.0
# 5                    1056       12     NaN      NaN          1.0
# 6                    1176        3     NaN      NaN          1.0
# 7                     222        1     1.0      1.0         10.0
# 8                     222        2     1.0      1.0         11.0
# 9                     222        3     NaN      NaN          3.0
# 10                    222        4     NaN      1.0          8.0
# 11                    222        5     NaN      1.0          7.0
# 12                    222       12     NaN      NaN          1.0
# 13                     26        1    86.0    104.0        201.0
# 14                     26        2   101.0    127.0        177.0
# 15                     26        3   104.0    123.0        242.0
# 16                     26        4    99.0    126.0        192.0
# 17                     26        5    79.0     91.0        143.0
# 18                     26       12     NaN      NaN          6.0
# 19                     34        1   730.0    793.0        384.0
# 20                     34        2   670.0    717.0        354.0
# 21                     34        3   762.0    805.0        394.0
# 22                     34        4   715.0    758.0        308.0
# 23                     34        5   595.0    630.0        269.0
# 24                     34       12     5.0      6.0          4.0
# 25                    471        1     9.0     10.0        269.0
# 26                    471        2    10.0     10.0        234.0
# 27                    471        3    17.0     17.0        224.0
# 28                    471        4    22.0     22.0        288.0
# 29                    471        5     7.0      7.0        230.0
# 30                    471       12     NaN      NaN         10.0
# 31                    531        1     NaN      NaN      20313.0
# 32                    531        2     NaN      NaN       7749.0
# 33                    531        3     NaN      NaN      13338.0
# 34                    531        4     NaN      NaN      45007.0
# 35                    531        5     NaN      NaN      46433.0
# 36                    531       12     NaN      NaN       2465.0
# 37                    538        5     NaN      NaN          1.0
# 38                     56        1    94.0    133.0        568.0
# 39                     56        2    83.0    107.0        603.0
# 40                     56        3    87.0    118.0        664.0
# 41                     56        4    84.0    116.0        697.0
# 42                     56        5    54.0     76.0        534.0
# 43                     56       12     3.0      4.0         26.0

# %%
aggregrated_df_monthly_count = (
    pivot_monthly_count
    .groupby('payer_account_id')
    .agg(
        total_inflow_count = ('InFlow', 'sum'),
        total_outflow_count = ('OutFlow', 'sum'),
        total_valuechain_count = ('Value Chain', 'sum'),
        monthly_inflow_count = ('InFlow', 'mean'),
        monthly_outflow_count = ('OutFlow', 'mean'),
        monthly_valuechain_count = ('Value Chain', 'mean'),
    )
    .reset_index()
)

# %%
aggregrated_df_monthly_count
# Out:
#   payer_account_id  total_inflow_count  total_outflow_count  \
# 0             1056                 2.0                  3.0
# 1             1176                 0.0                  0.0
# 2              222                 2.0                  4.0
# 3               26               469.0                571.0
# 4               34              3477.0               3709.0
# 5              471                65.0                 66.0
# 6              531                 0.0                  0.0
# 7              538                 0.0                  0.0
# 8               56               405.0                554.0
#
#    total_valuechain_count  monthly_inflow_count  monthly_outflow_count  \
# 0                    34.0                   1.0               1.000000
# 1                     1.0                   NaN                    NaN
# 2                    40.0                   1.0               1.000000
# 3                   961.0                  93.8             114.200000
# 4                  1713.0                 579.5             618.166667
# 5                  1255.0                  13.0              13.200000
# 6                135305.0                   NaN                    NaN
# 7                     1.0                   NaN                    NaN
# 8                  3092.0                  67.5              92.333333
#
#    monthly_valuechain_count
# 0                  5.666667
# 1                  1.000000
# 2                  6.666667
# 3                160.166667
# 4                285.500000
# 5                209.166667
# 6              22550.833333
# 7                  1.000000
# 8                515.333333

# %% [markdown]
# ### Reward Points

# %%
reward_agg = df.groupby('payer_account_id').agg({'reward_point': 'sum'})
reward_agg
# Out:
#                   reward_point
# payer_account_id
# 1056                      27.0
# 1176                       0.0
# 222                       11.0
# 26                       207.0
# 34                      2639.0
# 471                      180.0
# 531                        0.0
# 538                        0.0
# 56                       805.0

# %% [markdown]
# ### Lastest Transaction Date and Used Product

# %%
idx_max_date = df.groupby('payer_account_id')['dates'].idxmax()
result_df = df.loc[idx_max_date, ['payer_account_id', 'product_name', 'dates']]
result_df.rename(columns = {'product_name': 'latest_used_product', 'dates': 'latest_tran_date'}, inplace=True)
result_df
# Out:
#        payer_account_id   latest_used_product    latest_tran_date
# 145181             1056      NT Prepaid Topup 2023-05-21 19:34:59
# 38687              1176           Ncell Topup 2023-03-04 15:19:19
# 131529              222      NT Prepaid Topup 2023-05-16 14:58:00
# 151538               26             WorldLink 2023-05-24 20:46:04
# 151424               34            Send Money 2023-05-24 19:53:52
# 151230              471           Ncell Topup 2023-05-24 18:30:54
# 151728              531  Ncell Topup via Bank 2023-05-24 23:59:25
# 138639              538      NT Prepaid Topup 2023-05-18 18:48:37
# 151429               56           Ncell Topup 2023-05-24 19:57:46

# %% [markdown]
# ### Revenue

# %%
monthly_revenue= pd.pivot_table(df, index = ['payer_account_id', 'monthly'], values = 'revenue_amount', aggfunc = 'sum').reset_index()
monthly_revenue
# Out:
#    payer_account_id  monthly  revenue_amount
# 0              1056        1           11.37
# 1              1056        2           13.30
# 2              1056        3           16.85
# 3              1056        4           18.19
# 4              1056        5            8.94
# 5              1056       12            7.00
# 6              1176        3            0.28
# 7               222        1            8.36
# 8               222        2           10.51
# 9               222        3            1.95
# 10              222        4           23.06
# 11              222        5           19.65
# 12              222       12            1.01
# 13               26        1          330.80
# 14               26        2          284.86
# 15               26        3          276.75
# 16               26        4          347.82
# 17               26        5          292.27
# 18               26       12            0.59
# 19               34        1         3008.44
# 20               34        2         2151.73
# 21               34        3         2741.15
# 22               34        4         2248.44
# 23               34        5         1931.19
# 24               34       12           16.10
# 25              471        1          302.62
# 26              471        2          182.38
# 27              471        3          178.06
# 28              471        4          185.79
# 29              471        5          116.16
# 30              471       12            5.72
# 31              531        1        18167.84
# 32              531        2        22041.38
# 33              531        3        26072.69
# 34              531        4        28642.82
# 35              531        5        22591.33
# 36              531       12          505.81
# 37              538        5            0.04
# 38               56        1          826.98
# 39               56        2         1020.90
# 40               56        3         1495.02
# 41               56        4         1668.77
# 42               56        5         1430.36
# 43               56       12           22.50

# %%
revenue = (
    monthly_revenue
    .groupby('payer_account_id')
    .agg(
        monthly_average_lifetime_revenue = ('revenue_amount', 'mean'),
        total_revenue = ('revenue_amount', 'sum'),
    )
    .reset_index()
)

revenue
# Out:
#   payer_account_id  monthly_average_lifetime_revenue  total_revenue
# 0             1056                         12.608333          75.65
# 1             1176                          0.280000           0.28
# 2              222                         10.756667          64.54
# 3               26                        255.515000        1533.09
# 4               34                       2016.175000       12097.05
# 5              471                        161.788333         970.73
# 6              531                      19670.311667      118021.87
# 7              538                          0.040000           0.04
# 8               56                       1077.421667        6464.53

# %% [markdown]
# ### This Month's Revenue

# %%
latest_date = df['dates'].max()
latest_month_df = df[df['dates'].dt.month == latest_date.month]

this_month_revenue = latest_month_df.groupby('payer_account_id')['revenue_amount'].sum().reset_index(name = 'this_month_revenue')
this_month_revenue
# Out:
#   payer_account_id  this_month_revenue
# 0             1056                8.94
# 1              222               19.65
# 2               26              292.27
# 3               34             1931.19
# 4              471              116.16
# 5              531            22591.33
# 6              538                0.04
# 7               56             1430.36

# %% [markdown]
# ### Product Usage

# %%
product_usage = df.groupby('payer_account_id')['product_id'].count().reset_index().rename(columns={'product_id': 'product_usage'})
product_usage
# Out:
#   payer_account_id  product_usage
# 0             1056             39
# 1             1176              1
# 2              222             46
# 3               26           2001
# 4               34           8899
# 5              471           1386
# 6              531         135305
# 7              538              1
# 8               56           4051

# %% [markdown]
# ### Nth Used Product

# %%
product_counts = df.groupby(['payer_account_id', 'product_name'])['product_name'].count().reset_index(name='count')

product_counts
# Out:
#     payer_account_id                 product_name  count
# 0               1056              Dish Home Topup      1
# 1               1056             NT Prepaid Topup     27
# 2               1056                  Ncell Topup      2
# 3               1056  Nepal Electricity Authority      4
# 4               1056                   Send Money      4
# ..               ...                          ...    ...
# 219               56    eSewa to Garima Dev. Bank      1
# 220               56     eSewa to Global IME Bank      8
# 221               56       eSewa to NIC Asia Bank      7
# 222               56            eSewa to NMB Bank      6
# 223               56   eSewa to Sunrise Bank Ltd.      1
#
# [224 rows x 3 columns]

# %%
sorted_product_counts = product_counts.sort_values(by=['payer_account_id', 'count'], ascending=[True, False])

most_used_product = sorted_product_counts.groupby('payer_account_id').nth(0).reset_index()
second_most_used_product = sorted_product_counts.groupby('payer_account_id').nth(1).reset_index()
third_most_used_product = sorted_product_counts.groupby('payer_account_id').nth(2).reset_index()

# %%
most_used_product
# Out:
#    index payer_account_id                 product_name  count
# 0      1             1056             NT Prepaid Topup     27
# 1      6             1176                  Ncell Topup      1
# 2      8              222            NT Postpaid Topup     16
# 3     27               26                   Send Money    622
# 4     61               34                   Send Money   6926
# 5     85              471             NT Prepaid Topup    638
# 6    150              531            NT Topup via Bank  59806
# 7    194              538             NT Prepaid Topup      1
# 8    210               56  Nepal Electricity Authority   1233

# %%
result = pd.merge(most_used_product, second_most_used_product, on='payer_account_id', suffixes=('_most', '_second'), how='left')
result = pd.merge(result, third_most_used_product, on='payer_account_id', how='left')

# %%
result = result[['payer_account_id', 'product_name_most', 'product_name_second', 'product_name']]
result.columns = ['payer_account_id', 'most_used_product', 'second_most_used_product', 'third_most_used_product']
result
# Out:
#   payer_account_id            most_used_product     second_most_used_product  \
# 0             1056             NT Prepaid Topup  Nepal Electricity Authority
# 1             1176                  Ncell Topup                          NaN
# 2              222            NT Postpaid Topup                  Ncell Topup
# 3               26                   Send Money             NT Prepaid Topup
# 4               34                   Send Money  Nepal Electricity Authority
# 5              471             NT Prepaid Topup                  Ncell Topup
# 6              531            NT Topup via Bank         Ncell Topup via Bank
# 7              538             NT Prepaid Topup                          NaN
# 8               56  Nepal Electricity Authority                   Send Money
#
#    third_most_used_product
# 0               Send Money
# 1                      NaN
# 2         NT Prepaid Topup
# 3                  Cash In
# 4         NT Prepaid Topup
# 5               Send Money
# 6  Wordlink Topup via Bank
# 7                      NaN
# 8              Ncell Topup
