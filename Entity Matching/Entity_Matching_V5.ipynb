# %% [markdown]
# ### Changelog
#
# - Need to create dynamic data loading/preprocessing/saving (for any number of files)

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from Levenshtein import distance
from datetime import datetime 
import os

# %% [markdown]
# ### Loading Dataset

# %%
def load_df_from_dir(dir_path):
    csv_files = [f for f in os.listdir(dir_path) if f.endswith(".csv")]
    layouts = []

    for csv_file in csv_files:
        file_path = os.path.join(dir_path, csv_file)
        df = pd.read_csv(file_path)
        # df['source'] = os.path.splitext(csv_file)[0]
        layouts.append(df)
    
    return layouts

# %%
# layouts = load_df_from_dir('dataset_clean')
layouts = load_df_from_dir('results')

# %% [markdown]
# ### Save DF to CSV

# %%
# import os
# import pandas as pd

# def save_dfs_to_csv(layouts, output_dir):

#     os.makedirs(output_dir, exist_ok=True)
    
#     for i, df in enumerate(layouts, start=1):
#         file_name = f"layout{i}.csv"
#         file_path = os.path.join(output_dir, file_name)
#         df.to_csv(file_path, index=False)
#         print(f"Saved {file_path}")

# %% [markdown]
# ### Data Preprocessing

# %%
for layout in layouts:
    layout['last_modified_date'] = datetime.now()

def sanitize(df):
    return df.map(lambda x: x.replace(',', '').replace(' ', '').strip() if isinstance(x, str) else '' if pd.isna(x) else x)
    
def create_soup(df, df_, soup, soup_name):
    df[soup_name] = df_[soup].apply(lambda x: ' '.join(x.values.astype(str)).lower(), axis=1)

layout_copies = [layout.copy() for layout in layouts]
soup = ['Name', 'Date of Birth', 'Father_Name']

for layout, layout_copy, in zip(layouts, layout_copies):
    layout_copy = sanitize(layout_copy)
    create_soup(layout, layout_copy, soup, "soup")

# %% [markdown]
# ### Entity Matching

# %%
def combine_layouts(A, B, metric='cosine', threshold=0.8):
    def calculate_similarity(A, B, metric):
        if metric == 'cosine':
            tfidf = TfidfVectorizer(stop_words='english')
            combined_soup = pd.concat([A['soup'], B['soup']], ignore_index=True)
            tfidf.fit(combined_soup)
            tfidf_matrix_A = tfidf.transform(A['soup'])
            tfidf_matrix_B = tfidf.transform(B['soup'])
            similarity = cosine_similarity(tfidf_matrix_A, tfidf_matrix_B)
            similarity_df = pd.DataFrame(similarity, index=A.index, columns=B.index)
            idx_row = similarity_df.idxmax(axis=1)
            similarity_mask = similarity_df.max(axis=1) > threshold
        else:
            distance_matrix = pd.DataFrame([[distance(a, b) for b in B['soup']] for a in A['soup']], index=A.index, columns=B.index)
            idx_row = distance_matrix.idxmin(axis=1)
            similarity_mask = distance_matrix.min(axis=1) <= threshold
        return idx_row, similarity_mask

    def merge_data(A, B, idx_row, similarity_mask):
        combined_columns = list(set(A.columns) | set(B.columns))
        combined_data = pd.DataFrame(columns=combined_columns)
        for idx_A in A.index:
            if similarity_mask[idx_A]:
                idx_B = idx_row[idx_A]
                combined_row = A.loc[idx_A].combine_first(B.loc[idx_B])
                combined_row['source'] = f"{A.loc[idx_A]['source']}, {B.loc[idx_B]['source']}"
                combined_row['last_modified_date'] = datetime.now()
            else:
                combined_row = A.loc[idx_A]
            combined_data = pd.concat([combined_data, combined_row.to_frame().T], ignore_index=True)
        new_records = B.loc[~B.index.isin(idx_row[similarity_mask].values)]
        return pd.concat([combined_data, new_records], ignore_index=True)

    idx_row, similarity_mask = calculate_similarity(A, B, metric)
    return merge_data(A, B, idx_row, similarity_mask)

# %% [markdown]
# ### Saving Results

# %% [markdown]
# #### Save Intermittent Result

# %%
# def save_layouts(layouts, save_path):
#     final_df = layouts[0]
#     results = [final_df] 

#     initial_part = "1"   
#     for i, df in enumerate(layouts[1:], start=2):
#         final_df = combine_layouts(final_df, df)
#         results.append(final_df)
        
#         initial_part += str(i)
#         final_df.to_csv(f"./{save_path}/result{initial_part}.csv", index=False)
    
#     return final_df, results

# %%
# final_df, results = save_layouts(layouts, 'results')

# %% [markdown]
# #### Save final result only

# %%
# def save_layouts(layouts, save_path):
#     final_df = layouts[0]

#     for df in layouts[1:]:
#         final_df = combine_layouts(final_df, df)
    
#     final_result_path = os.path.join(save_path, 'final_result.csv')
#     final_df.to_csv(final_result_path, index=False)
#     return final_df

# %%
# final_df = save_layouts(layouts, 'results')

# %% [markdown]
# #### Save final_result and delete source files if successful

# %%
import os
import glob

def save_layouts(layouts, save_path, save_filename):
    final_df = layouts[0]

    for df in layouts[1:]:
        final_df = combine_layouts(final_df, df)
    
    final_result_path = os.path.join(save_path, save_filename)
    
    try:
        final_df.to_csv(final_result_path, index=False)
    except Exception as e:
        print(f"Error saving final result: {e}")
        return None

    # If save is successful, delete all other files in save_path except final_result
    files = glob.glob(os.path.join(save_path, '*'))
    for f in files:
        if f != final_result_path:
            os.remove(f)

    return final_df

# %%
final_df = save_layouts(layouts, 'results', 'final_result.csv')

# %%
final_df
# Out:
#     License Number votersAge Date of Birth  \
# 0   15-05-58353205        45    1990-01-01
# 1   21-08-00435579        38    1991-02-02
# 2   93-12-35351480        52    1992-03-03
# 3   65-03-68139881        30    1993-04-04
# 4              NaN        27    1994-05-05
# 5   82-09-81734599        41    1995-06-06
# 6              NaN        36    1996-07-07
# 7   98-03-72394228        50    1997-08-08
# 8              NaN        43    1998-09-09
# 9   42-08-02614125        34    1999-10-10
# 10  15-06-41273848        39    2000-11-11
# 11  31-01-32329238        48    2001-12-12
# 12  73-02-11496212        31    1989-01-13
# 13  94-08-09289547        29    1988-02-14
# 14             NaN        44    1987-03-15
# 15  17-11-63791321        53    1986-04-16
# 16             NaN        37    1985-05-17
# 17  68-10-56792613        28    1984-06-18
# 18  28-09-97969690        46    1983-07-19
# 19             NaN        40    1982-08-20
# 20  14-11-40056582       NaN           NaN
# 21  26-03-50185868       NaN           NaN
# 22  68-01-80388982       NaN           NaN
# 23  98-09-16879291       NaN           NaN
# 24  71-03-35575299       NaN           NaN
# 25  89-04-95690392       NaN           NaN
#
#                                          source  \
# 0   layout1, layout2, layout3, layout4, layout5
# 1   layout1, layout2, layout3, layout4, layout5
# 2   layout1, layout2, layout3, layout4, layout5
# 3   layout1, layout2, layout3, layout4, layout5
# 4            layout1, layout2, layout3, layout4
# 5   layout1, layout2, layout3, layout4, layout5
# 6            layout1, layout2, layout3, layout4
# 7   layout1, layout2, layout3, layout4, layout5
# 8            layout1, layout2, layout3, layout4
# 9   layout1, layout2, layout3, layout4, layout5
# 10  layout1, layout2, layout3, layout4, layout5
# 11  layout1, layout2, layout3, layout4, layout5
# 12  layout1, layout2, layout3, layout4, layout5
# 13  layout1, layout2, layout3, layout4, layout5
# 14           layout1, layout2, layout3, layout4
# 15  layout1, layout2, layout3, layout4, layout5
# 16           layout1, layout2, layout3, layout4
# 17  layout1, layout2, layout3, layout4, layout5
# 18  layout1, layout2, layout3, layout4, layout5
# 19           layout1, layout2, layout3, layout4
# 20                                      layout5
# 21                                      layout5
# 22                                      layout5
# 23                                      layout5
# 24                                      layout5
# 25                                      layout5
#
#                                               soup             Name  \
# 0              ramthapa 1990-01-01 rambahadurthapa        Ram Thapa
# 1       sitashrestha 1991-02-02 hariprasadshrestha    Sita Shrestha
# 2         harigurung 1992-03-03 gopalkrishnagurung      Hari Gurung
# 3             gitatamang 1993-04-04 shyamlaltamang      Gita Tamang
# 4              mohanlama 1994-05-05 krishnarajlama       Mohan Lama
# 5          radhamagar 1995-06-06 narayankumarmagar      Radha Magar
# 6          krishnarai 1996-07-07 govindabahadurrai      Krishna Rai
# 7       saritasherpa 1997-08-08 shivanarayansherpa    Sarita Sherpa
# 8     bikashkarki 1998-09-09 bhagirathbahadurkarki     Bikash Karki
# 9    nishabhandari 1999-10-10 suryabahadurbhandari   Nisha Bhandari
# 10   aaravadhikari 2000-11-11 rajanbahaduradhikari   Aarav Adhikari
# 11        snehajoshi 2001-12-12 rameshbahadurjoshi      Sneha Joshi
# 12         pratikshahi 1989-01-13 sureshkumarshahi     Pratik Shahi
# 13     anjubhattarai 1988-02-14 dineshrajbhattarai   Anju Bhattarai
# 14  manishmaharjan 1987-03-15 bijaybahadurmaharjan  Manish Maharjan
# 15               pujakc 1986-04-16 rameshbahadurkc          Puja KC
# 16       anilkhadka 1985-05-17 rajeshbahadurkhadka      Anil Khadka
# 17         ritarimal 1984-06-18 ganeshbahadurrimal       Rita Rimal
# 18   pratikshadahal 1983-07-19 santoshbahadurdahal  Pratiksha Dahal
# 19   dipeshpokharel 1982-08-20 shyamsundarpokharel  Dipesh Pokharel
# 20                       mohanlama  krishnarajlama       Mohan Lama
# 21                                    krishnarai        Krishna Rai
# 22              bikashkarki  bhagirathbahadurkarki     Bikash Karki
# 23                                manishmaharjan    Manish Maharjan
# 24                                    anilkhadka        Anil Khadka
# 25             dipeshpokharel  shyamsundarpokharel  Dipesh Pokharel
#
#    Customer Code Blood Group  SC Number                Temporary_Address  ...  \
# 0       21216874         AB+  001.01.01        Gongabu, Kathmandu, Nepal  ...
# 1       22359363         AB-  001.01.02         New Road, Pokhara, Nepal  ...
# 2       33485241          B-  001.01.03        Pulchowk, Lalitpur, Nepal  ...
# 3       45475489          A-  001.01.04       Bagbazar, Kathmandu, Nepal  ...
# 4       56562139         NaN  001.01.05                              NaN  ...
# 5       67698214          B-  001.01.06       Chabahil, Kathmandu, Nepal  ...
# 6       78714635         NaN  001.01.07      Kumaripati, Lalitpur, Nepal  ...
# 7       89847326          A-  001.01.08  New Baneshwor, Kathmandu, Nepal  ...
# 8       91953421         NaN  001.01.09         Boudha, Kathmandu, Nepal  ...
# 9       10203847          A-  001.01.10        Kalanki, Kathmandu, Nepal  ...
# 10      12113982          O+  001.01.11          Sanepa, Lalitpur, Nepal  ...
# 11      13122547         AB+  001.01.12    Putalisadak, Kathmandu, Nepal  ...
# 12      13235698          O-  001.01.13        Tinkune, Kathmandu, Nepal  ...
# 13      14247652         AB-  001.01.14     Sinamangal, Kathmandu, Nepal  ...
# 14      15158964         NaN  001.01.15         Thamel, Kathmandu, Nepal  ...
# 15      16169853         AB-  001.01.16      Jawalakhel, Lalitpur, Nepal  ...
# 16      17375246         NaN  001.01.17      Maitighar, Kathmandu, Nepal  ...
# 17      18383569          B-  001.01.18    Buddhanagar, Kathmandu, Nepal  ...
# 18      19294258         AB+  001.01.19          Naxal, Kathmandu, Nepal  ...
# 19      20305417         NaN  001.01.20                              NaN  ...
# 20           NaN          A+        NaN       Balkumari, Lalitpur, Nepal  ...
# 21           NaN         AB+        NaN      Kumaripati, Lalitpur, Nepal  ...
# 22           NaN          B-        NaN         Boudha, Kathmandu, Nepal  ...
# 23           NaN          B+        NaN         Thamel, Kathmandu, Nepal  ...
# 24           NaN         AB-        NaN      Maitighar, Kathmandu, Nepal  ...
# 25           NaN          A-        NaN       Gaushala, Kathmandu, Nepal  ...
#
#         Citizenship Number              Father_Name      Mother Name  \
# 0   624-93227-32431/660086        Ram Bahadur Thapa      Laxmi Thapa
# 1   747-42087-31417/584714     Hari Prasad Shrestha     Radha Sharma
# 2   389-45382-93886/821590     Gopal Krishna Gurung    Gita Adhikari
# 3   571-38785-99733/440035         Shyam Lal Tamang         Mina Rai
# 4                      NaN         Krishna Raj Lama    Kalpana Karki
# 5   033-51347-62581/380746      Narayan Kumar Magar      Nima Gurung
# 6                      NaN      Govinda Bahadur Rai    Saru Shrestha
# 7   323-37869-95909/623481     Shiva Narayan Sherpa    Nanu Maharjan
# 8                      NaN  Bhagirath Bahadur Karki     Lhamu Tamang
# 9   272-28301-42325/881177   Surya Bahadur Bhandari          Lila KC
# 10  575-80644-44438/883300   Rajan Bahadur Adhikari   Chandra Khadka
# 11  599-66155-86484/518801     Ramesh Bahadur Joshi     Tulasa Magar
# 12  371-38746-28131/634277       Suresh Kumar Shahi      Ganga Yadav
# 13  506-21915-16175/214975     Dinesh Raj Bhattarai     Sunita Bista
# 14                     NaN   Bijay Bahadur Maharjan      Gita Dhakal
# 15  697-65333-88172/166613        Ramesh Bahadur KC       Laxmi Pant
# 16                     NaN    Rajesh Bahadur Khadka     Sarita Joshi
# 17  542-42953-82512/112038     Ganesh Bahadur Rimal  Meena Bhattarai
# 18  697-25014-99353/663054    Santosh Bahadur Dahal     Manju Gurung
# 19                     NaN    Shyam Sundar Pokharel        Rita Lama
# 20  864-17331-40021/961722         Krishna Raj Lama              NaN
# 21  068-37653-84341/852787                      NaN              NaN
# 22  406-94259-70142/249811  Bhagirath Bahadur Karki              NaN
# 23  157-92240-30969/930555                      NaN              NaN
# 24  395-60019-88104/590785                      NaN              NaN
# 25  769-44973-94012/456699    Shyam Sundar Pokharel              NaN
#
#    National Id  Gender                      Permanent_Address  \
# 0       AB123C    Male            Baluwatar, Kathmandu, Nepal
# 1       DE456F  Female               Lakeside, Pokhara, Nepal
# 2       GH789I    Male  Chitwan National Park, Chitwan, Nepal
# 3       JK012L  Female              Biratnagar, Morang, Nepal
# 4       MN345O    Male              Bharatpur, Chitwan, Nepal
# 5       PQ678R  Female               Butwal, Rupandehi, Nepal
# 6       ST901U    Male              Hetauda, Makwanpur, Nepal
# 7       VW234X  Female               Janakpur, Dhanusa, Nepal
# 8       YZ567A    Male                Nepalgunj, Banke, Nepal
# 9       BC890D  Female                 Dharan, Sunsari, Nepal
# 10      EF123G    Male                Birtamode, Jhapa, Nepal
# 11      HI456J  Female              Dhangadhi, Kailali, Nepal
# 12      KL789M    Male                Itahari, Sunsari, Nepal
# 13      NO012P  Female            Bhaktapur, Bhaktapur, Nepal
# 14      QR345S    Male             Kirtipur, Kathmandu, Nepal
# 15      TU678V  Female              Lalitpur, Lalitpur, Nepal
# 16      WX901Y    Male                   Ghorahi, Dang, Nepal
# 17      ZA234B  Female                   Tansen, Palpa, Nepal
# 18      CD567E    Male                  Bidur, Nuwakot, Nepal
# 19      FG890H  Female                    Damak, Jhapa, Nepal
# 20         NaN     NaN              Bharatpur, Chitwan, Nepal
# 21         NaN     NaN              Hetauda, Makwanpur, Nepal
# 22         NaN     NaN                Nepalgunj, Banke, Nepal
# 23         NaN     NaN             Kirtipur, Kathmandu, Nepal
# 24         NaN     NaN                   Ghorahi, Dang, Nepal
# 25         NaN     NaN                    Damak, Jhapa, Nepal
#
#             last_modified_date       SpouseName Customer ID Mobile Number
# 0   2024-05-30 15:12:55.479627       Sita Thapa        3245    1234567890
# 1   2024-05-30 15:12:55.479627      Ravi Sharma        3246    2345678901
# 2   2024-05-30 15:12:55.479627    Maya Adhikari        3247    3456789012
# 3   2024-05-30 15:12:55.479627        Surya Rai        3248    4567890123
# 4   2024-05-30 15:12:55.437012     Sarita Karki        3249    5678901234
# 5   2024-05-30 15:12:55.493584     Pemba Gurung        3250    6789012345
# 6   2024-05-30 15:12:55.437012   Laxmi Shrestha        3251    7890123456
# 7   2024-05-30 15:12:55.493584     Raj Maharjan        3252    8901234567
# 8   2024-05-30 15:12:55.445465      Pema Tamang        3253    9012345678
# 9   2024-05-30 15:12:55.493584        Manish KC        3254     123456789
# 10  2024-05-30 15:12:55.500113     Nisha Khadka        3255    1234567800
# 11  2024-05-30 15:12:55.500113      Kamal Magar        3256    2345678902
# 12  2024-05-30 15:12:55.500113       Sita Yadav        3257    3456789013
# 13  2024-05-30 15:12:55.500113       Mina Bista        3258    4567890124
# 14  2024-05-30 15:12:55.459295       Ram Dhakal        3259    5678901235
# 15  2024-05-30 15:12:55.500113       Radha Pant        3260    6789012346
# 16  2024-05-30 15:12:55.464292       Amit Joshi        3261    7890123457
# 17  2024-05-30 15:12:55.509151  Anita Bhattarai        3262    8901234568
# 18  2024-05-30 15:12:55.509151      Sanu Gurung        3263    9012345679
# 19  2024-05-30 15:12:55.467572        Hari Lama        3264     123456790
# 20  2024-05-30 15:12:55.299395              NaN         NaN    5678901234
# 21  2024-05-30 15:12:55.299395              NaN         NaN    7890123456
# 22  2024-05-30 15:12:55.299395              NaN         NaN    9012345678
# 23  2024-05-30 15:12:55.299395              NaN         NaN    5678901235
# 24  2024-05-30 15:12:55.299395              NaN         NaN    7890123457
# 25  2024-05-30 15:12:55.299395              NaN         NaN     123456790
#
# [26 rows x 22 columns]
